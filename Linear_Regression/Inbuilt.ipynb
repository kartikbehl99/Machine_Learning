# %% [markdown]
# # Imports

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
boston = datasets.load_boston()
df = pd.DataFrame(boston.data)
df.columns = boston.feature_names

# %% [markdown]
# # Inbuilt linear regression

# %%
clf = LinearRegression(fit_intercept = True)
x_train, x_test, y_train, y_test = train_test_split(boston.data, boston.target)
clf.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.score(x_test, y_test)
# Out:
# 0.7399027271086929

# %%
clf.coef_
# Out:
# array([-1.08501957e-01,  5.13230671e-02,  1.62978885e-02,  2.89430930e+00,
#        -1.89659024e+01,  3.75330136e+00,  4.68946315e-03, -1.42626025e+00,
#         3.28893667e-01, -1.24163579e-02, -9.40813270e-01,  8.65568330e-03,
#        -5.09193697e-01])

# %%
clf.intercept_
# Out:
# 36.562536121202356

# %% [markdown]
# # Plotting the graph

# %%
plt.scatter(boston.data[:,4], boston.target)
predicted = clf.predict(boston.data)
plt.scatter(boston.data[:,4], predicted)
